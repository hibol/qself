# %%
from os import listdir
from matplotlib import pyplot as pl
import pandas as pd
import numpy as np

from scipy import stats

import warnings

warnings.filterwarnings(action='once')

# %%
path = "./selected_raw_data/"

# %%
# edge = 1 -> rising
# edge = 0 -> falling
def zero_crosses(data, edge):
    if edge==1:
        return np.logical_and((x[:-1]*x[1:] < 0), (x[1:] < 0)).sum()
    elif edge==0:
        return np.logical_and((x[:-1]*x[1:] < 0), (x[1:] > 0)).sum()

# %% [markdown]
# ## Import data
# Steps for each file :
# - print filename (useful to access data later)
# - create a dataframe from the values inside the file
# - clean timestamp in order to get a column indicating the elapsed time in seconds

# %%
data ={}
for f in listdir(path):
    if 'lud' in f or 'A' in f:
        continue
    data[f] = pd.read_csv(path+f)
    start_time = data[f]["timestamp"][0]
    data[f]["timestamp"] = (data[f]["timestamp"]-start_time)/1000

# %%
ex = data['abdos_f5_manon1.csv']
x = np.array(ex['x'])
((x[:-1] * x[1:]) < 0).sum()
# Out:
# 21

# %%
for f in data:
    if "abdos" in f:
        data[f].plot(x="timestamp", y=['x', 'y', 'z'], kind='line', title=f, grid=True)
        pl.ylabel('acceleration [N/kg]')
        pl.xlabel('time [s]')
        pl.xticks(np.arange(min(data[f]["timestamp"]), max(data[f]["timestamp"]), step=2))
        pl.show()
        
        x = np.array(data[f]['x'])
        print('x zero crossing : ' +str(zero_crosses(x, 1)))
# Out:
# c:\users\ludivine\anaconda2\envs\server\lib\site-packages\pandas\plotting\_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
# x zero crossing : 10
# x zero crossing : 11
# x zero crossing : 18
# x zero crossing : 3

# %%
for f in data:
    if "squats" in f:
        data[f].plot(x="timestamp", y=['x', 'y', 'z'], kind='line', title=f, grid=True)
        pl.ylabel('acceleration [N/kg]')
        pl.xlabel('time [s]')
        pl.xticks(np.arange(min(data[f]["timestamp"]), max(data[f]["timestamp"]), step=2))
        pl.show()
        
        x = np.array(data[f]['x'])+7.5
        y = np.array(data[f]['y'])+5
        print('x zero crossing : ' +str(zero_crosses(x, 0)))
        print('y zero crossing : ' +str(zero_crosses(y, 0)))
# Out:
# c:\users\ludivine\anaconda2\envs\server\lib\site-packages\pandas\plotting\_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
# x zero crossing : 9
# y zero crossing : 9
# x zero crossing : 17
# y zero crossing : 17
# x zero crossing : 12
# y zero crossing : 12
# x zero crossing : 13
# y zero crossing : 13

# %%
for f in data:
    if "dorsaux" in f:
        data[f].plot(x="timestamp", y=['x', 'y', 'z'], kind='line', title=f, grid=True)
        pl.ylabel('acceleration [N/kg]')
        pl.xlabel('time [s]')
        pl.xticks(np.arange(min(data[f]["timestamp"]), max(data[f]["timestamp"]), step=2))
        pl.show()
        
        x = np.array(data[f]['x'])
        z = np.array(data[f]['z'])-8
        print('x zero crossing : ' +str(zero_crosses(x, 1)))
        print('z zero crossing : ' +str(zero_crosses(z, 1)))
# Out:
# c:\users\ludivine\anaconda2\envs\server\lib\site-packages\pandas\plotting\_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
# x zero crossing : 12
# z zero crossing : 12
# x zero crossing : 9
# z zero crossing : 9
# x zero crossing : 19
# z zero crossing : 19
# x zero crossing : 20
# z zero crossing : 20

# %%
for f in data:
    if "corde" in f:
        data[f].plot(x="timestamp", y=['x', 'y', 'z'], kind='line', title=f, grid=True)
        pl.ylabel('acceleration [N/kg]')
        pl.xlabel('time [s]')
        pl.xticks(np.arange(min(data[f]["timestamp"]), max(data[f]["timestamp"]), step=2))
        pl.show()
        
        x = np.array(data[f]['x'])
        y = np.array(data[f]['y'])
        z = np.array(data[f]['z'])
        print('x zero crossing : ' +str(zero_crosses(x, 0)))
        print('y zero crossing : ' +str(zero_crosses(y, 0)))
        print('z zero crossing : ' +str(zero_crosses(z, 0)))
# Out:
# c:\users\ludivine\anaconda2\envs\server\lib\site-packages\pandas\plotting\_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
# x zero crossing : 5
# y zero crossing : 5
# z zero crossing : 5
# x zero crossing : 11
# y zero crossing : 11
# z zero crossing : 11
# x zero crossing : 14
# y zero crossing : 14
# z zero crossing : 14
# x zero crossing : 17
# y zero crossing : 17
# z zero crossing : 17
